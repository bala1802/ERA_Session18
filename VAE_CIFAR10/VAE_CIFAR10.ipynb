# %% [markdown]
# <a href="https://colab.research.google.com/github/bala1802/ERA_Session18/blob/main/VAE_CIFAR10/VAE_CIFAR10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Session-18
# Out:
# /content/drive/MyDrive/Session-18

# %%
cd ERA_Session18/
# Out:
# /content/drive/MyDrive/Session-18/ERA_Session18

# %%
# !git pull

# %%
# !pip install -r requirements.txt --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 716.4/716.4 kB 11.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.8/300.8 kB 28.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 806.1/806.1 kB 52.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 330.0/330.0 kB 31.2 MB/s eta 0:00:00

# %%
cd VAE_CIFAR10/
# Out:
# /content/drive/MyDrive/Session-18/ERA_Session18/VAE_CIFAR10

# %%
import dataset
import train
from vae_model import VAE
import data_visualization

# %% [markdown]
# #### Load the data

# %%
train_dataloader = dataset.get_dataloader(train=True, path='/content/drive/MyDrive/Session-18/data')
test_dataloader = dataset.get_dataloader(train=False, path='/content/drive/MyDrive/Session-18/data')
# Out:
# Files already downloaded and verified
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 12, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Files already downloaded and verified

# %% [markdown]
# #### Model Training

# %%
len(train_dataloader)
# Out:
# 2084

# %%
model, trainer = train.train(train_dataloader = train_dataloader, val_dataloader=test_dataloader)
# Out:
# INFO:lightning_fabric.utilities.seed:Global seed set to 1234
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.utilities.rank_zero:You are using a CUDA device ('NVIDIA A100-SXM4-40GB') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name     | Type        | Params
# -----------------------------------------
# 0 | encoder  | ResNet18Enc | 11.7 M
# 1 | decoder  | ResNet18Dec | 10.6 M
# 2 | chConv1  | Conv2d      | 1.8 K
# 3 | chout    | Linear      | 576 K
# 4 | bce_loss | BCELoss     | 0
# -----------------------------------------
# 22.9 M    Trainable params
# 0         Non-trainable params
# 22.9 M    Total params
# 91.643    Total estimated model params size (MB)
# /usr/local/lib/python3.10/dist-packages/lightning_fabric/loggers/csv_logs.py:188: UserWarning: Experiment logs directory logs/lightning_logs/version_0 exists and is not empty. Previous log files in this directory will be deleted when the new ones are saved!
#   rank_zero_warn(
# Sanity Checking: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 0: Validation loss 44.167598724365234
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 0: Validation loss 21.979270935058594
# ****Training****
# Epoch 0: Train loss 27.358530044555664
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 1: Validation loss 21.252653121948242
# ****Training****
# Epoch 1: Train loss 24.355377197265625
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 2: Validation loss 20.86927032470703
# ****Training****
# Epoch 2: Train loss 23.11864471435547
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 3: Validation loss 20.610782623291016
# ****Training****
# Epoch 3: Train loss 22.38457489013672
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 4: Validation loss 20.41366958618164
# ****Training****
# Epoch 4: Train loss 21.899620056152344
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 5: Validation loss 20.2344913482666
# ****Training****
# Epoch 5: Train loss 21.541709899902344
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 6: Validation loss 20.074420928955078
# ****Training****
# Epoch 6: Train loss 21.253116607666016
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 7: Validation loss 19.93541717529297
# ****Training****
# Epoch 7: Train loss 21.012168884277344
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 8: Validation loss 19.802841186523438
# ****Training****
# Epoch 8: Train loss 20.805328369140625
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 9: Validation loss 19.686967849731445
# ****Training****
# Epoch 9: Train loss 20.62483787536621
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 10: Validation loss 19.583297729492188
# ****Training****
# Epoch 10: Train loss 20.464895248413086
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 11: Validation loss 19.485733032226562
# ****Training****
# Epoch 11: Train loss 20.319143295288086
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 12: Validation loss 19.4024658203125
# ****Training****
# Epoch 12: Train loss 20.184818267822266
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 13: Validation loss 19.318958282470703
# ****Training****
# Epoch 13: Train loss 20.061519622802734
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 14: Validation loss 19.23850440979004
# ****Training****
# Epoch 14: Train loss 19.9486083984375
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 15: Validation loss 19.164535522460938
# ****Training****
# Epoch 15: Train loss 19.843637466430664
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 16: Validation loss 19.100337982177734
# ****Training****
# Epoch 16: Train loss 19.745113372802734
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 17: Validation loss 19.035200119018555
# ****Training****
# Epoch 17: Train loss 19.65265464782715
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 18: Validation loss 18.977222442626953
# ****Training****
# Epoch 18: Train loss 19.56557846069336
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 19: Validation loss 18.92708969116211
# ****Training****
# Epoch 19: Train loss 19.482696533203125
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 20: Validation loss 18.879568099975586
# ****Training****
# Epoch 20: Train loss 19.403738021850586
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 21: Validation loss 18.833478927612305
# ****Training****
# Epoch 21: Train loss 19.329174041748047
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 22: Validation loss 18.7888240814209
# ****Training****
# Epoch 22: Train loss 19.257076263427734
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 23: Validation loss 18.75112533569336
# ****Training****
# Epoch 23: Train loss 19.188562393188477
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 24: Validation loss 18.725772857666016
# ****Training****
# Epoch 24: Train loss 19.123489379882812
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 25: Validation loss 18.693586349487305
# ****Training****
# Epoch 25: Train loss 19.060367584228516
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 26: Validation loss 18.66045379638672
# ****Training****
# Epoch 26: Train loss 18.999835968017578
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 27: Validation loss 18.63034439086914
# ****Training****
# Epoch 27: Train loss 18.942363739013672
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 28: Validation loss 18.604969024658203
# ****Training****
# Epoch 28: Train loss 18.885536193847656
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 29: Validation loss 18.58266258239746
# ****Training****
# Epoch 29: Train loss 18.830366134643555
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 30: Validation loss 18.55964469909668
# ****Training****
# Epoch 30: Train loss 18.777034759521484
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 31: Validation loss 18.53812026977539
# ****Training****
# Epoch 31: Train loss 18.725133895874023
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 32: Validation loss 18.51874351501465
# ****Training****
# Epoch 32: Train loss 18.674814224243164
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 33: Validation loss 18.500329971313477
# ****Training****
# Epoch 33: Train loss 18.626083374023438
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 34: Validation loss 18.482681274414062
# ****Training****
# Epoch 34: Train loss 18.578672409057617
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 35: Validation loss 18.46574592590332
# ****Training****
# Epoch 35: Train loss 18.532794952392578
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 36: Validation loss 18.452680587768555
# ****Training****
# Epoch 36: Train loss 18.48830223083496
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 37: Validation loss 18.442785263061523
# ****Training****
# Epoch 37: Train loss 18.44527244567871
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 38: Validation loss 18.434518814086914
# ****Training****
# Epoch 38: Train loss 18.403522491455078
# Validation: 0it [00:00, ?it/s]
# ****Validation****
# Epoch 39: Validation loss 18.426118850708008
# ****Training****
# Epoch 39: Train loss 18.363391876220703
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=40` reached.

# %%
data_visualization.plot_metrics(trainer=trainer)
# Out:
#         lr-Adam      elbo         kl   recon_loss  multilabel loss  total loss
# epoch
# NaN    0.000147       NaN        NaN          NaN              NaN         NaN
# 0.0         NaN  3.216627   6.907477  3209.719482         4.306737   36.473007
# NaN    0.000194       NaN        NaN          NaN              NaN         NaN
# 0.0         NaN  3.162151   7.849709  3154.301514         4.548057   36.169567
# NaN    0.000242       NaN        NaN          NaN              NaN         NaN
# ...         ...       ...        ...          ...              ...         ...
# 4.0         NaN  1.928025  35.205471  1892.819702         2.332207   21.612457
# NaN    0.009553       NaN        NaN          NaN              NaN         NaN
# 4.0         NaN  1.665071  32.544140  1632.526733         1.901821   18.552532
# NaN    0.009601       NaN        NaN          NaN              NaN         NaN
# 4.0         NaN  1.965021  33.279522  1931.741943         2.110146   21.760359
#
# [400 rows x 6 columns]

# %%
data_visualization.plot_results(train_dataloader=train_dataloader, model=model)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 12, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-5dcd34ec71a5> in <cell line: 1>()
# ----> 1 data_visualization.plot_results(train_dataloader=train_dataloader, model=model)
#
# /content/drive/MyDrive/Session-18/ERA_Session18/VAE_CIFAR10/data_visualization.py in plot_results(train_dataloader, model)
#      44     x, y, y_changed  = val_batch['image'],val_batch['correct_label'],val_batch['changed_label']
#      45     wrong_y = torch.flip(y_changed,[0])
# ---> 46     generate_image(x,y,wrong_y, model.to('cuda'))
#
# /content/drive/MyDrive/Session-18/ERA_Session18/VAE_CIFAR10/data_visualization.py in generate_image(x, y, wrong_y, model, num_predictions)
#      33
#      34           ax = fig.add_subplot(5,5,idx + 1,xticks=[],yticks=[])
# ---> 35           img = x_hat[idx].to('cpu')
#      36           plt.imshow(img.permute(1,2,0))
#      37           ax.set_title(f"Label/Image: {cifar10_labels[wrong_y[idx]]} / {cifar10_labels[y[idx]]}")
#
# IndexError: index 24 is out of bounds for dimension 0 with size 24
