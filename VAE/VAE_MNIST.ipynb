# %% [markdown]
# <a href="https://colab.research.google.com/github/bala1802/ERA_Session18/blob/main/VAE/VAE_MNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Session-18
# Out:
# /content/drive/MyDrive/Session-18

# %%
# !git pull
# !git clone https://github.com/bala1802/ERA_Session18.git

# %%
cd /content/drive/MyDrive/Session-18/ERA_Session18
# Out:
# /content/drive/MyDrive/Session-18/ERA_Session18

# %%
# !pip install -r requirements.txt --quiet

# %%
cd VAE_MNIST
# Out:
# /content/drive/MyDrive/Session-18/ERA_Session18/VAE_MNIST

# %%
import dataset
import train
from vae_model import VAE
import data_visualization

# %% [markdown]
# #### Load data

# %%
train_dataloader = dataset.get_dataloader(train=True, path='/content/drive/MyDrive/Session-18/data')
test_dataloader = dataset.get_dataloader(train=False, path='/content/drive/MyDrive/Session-18/data')

# %% [markdown]
# #### Model Training

# %%
model, trainer = train.train(train_dataloader = train_dataloader, val_dataloader=test_dataloader)
# Out:
# INFO:lightning_fabric.utilities.seed:Global seed set to 1234
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# WARNING:lightning_fabric.loggers.csv_logs:Missing logger folder: logs/lightning_logs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name     | Type            | Params
# ---------------------------------------------
# 0 | encConv1 | Conv2d          | 608
# 1 | encConv2 | Conv2d          | 18.5 K
# 2 | fc_mu    | Linear          | 9.4 M
# 3 | fc_var   | Linear          | 9.4 M
# 4 | deFC1    | Linear          | 9.8 M
# 5 | deConv1  | ConvTranspose2d | 18.5 K
# 6 | deConv2  | ConvTranspose2d | 289
# ...

# %% [markdown]
# #### Visualize the training metrics

# %%
data_visualization.plot_metrics(trainer=trainer)
# Out:
#         lr-Adam      elbo          kl  multilabel loss  total loss
# epoch
# NaN    0.000015       NaN         NaN              NaN         NaN
# 0.0         NaN  1.199428    6.642180         4.668497    5.867925
# NaN    0.000020       NaN         NaN              NaN         NaN
# 0.0         NaN  1.190471    4.955090         4.587848    5.778319
# NaN    0.000026       NaN         NaN              NaN         NaN
# ...         ...       ...         ...              ...         ...
# 5.0         NaN  1.084635  120.034866         0.152540    1.237175
# NaN    0.000980       NaN         NaN              NaN         NaN
# 5.0         NaN  1.062577   95.836014         0.044231    1.106808
# NaN    0.000978       NaN         NaN              NaN         NaN
# 5.0         NaN  1.081676   81.477875         0.206066    1.287742
#
# [400 rows x 5 columns]

# %% [markdown]
# #### Generate Images

# %%
data_visualization.plot_results(train_dataloader=train_dataloader, model=model)
